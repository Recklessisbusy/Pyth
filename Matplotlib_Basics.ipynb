# %% [markdown]
# <center> <h1 style="color:red"> Matplotlib Compherensive </h1> </center>

# %% [markdown]
# <center> <h2 style="color:blue"> Fundamental Charts </h2> </center>

# %% [markdown]
# ![charts.png](attachment:charts.png)

# %% [markdown]
# <center> <h2 style="color:blue"> Comparison </h2> </center>

# %% [markdown]
# ![1_cixzdO-gByLAInPcct5jvw.jpg](attachment:1_cixzdO-gByLAInPcct5jvw.jpg)

# %% [markdown]
# <center> <h2 style="color:blue"> Basics of Charts </h2> </center>

# %% [markdown]
# Matplotlib is a library for __creating static, animated, and interactive visualizations__ in Python
# - Matlotlib __figures__ derived from __Matlab__ figures.
# - Especially works with collections such as numpy ndarrays, lists
# - Handles big data easily.

# %% [markdown]
# <center> <h2 style="color:blue"> Most Basic Chart </h2> </center>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = [1, 2, 3, 4, 5]
y_data = [1, 4, 9, 16, 25]

# %%
plt.plot(x_data, y_data)
plt.show()

# %% [markdown]
# <center> <h2 style="color:blue"> Basic Configurations </h2> </center>

# %%
x_data = [1, 2, 3, 4, 5]
y_data = [1, 4, 9, 16, 25]

# %% [markdown]
# __Hex Color Codes:__ https://htmlcolorcodes.com/

# %% [markdown]
# __Line styles:__
# https://www.geeksforgeeks.org/linestyles-in-matplotlib-python/

# %%
plt.plot(x_data, y_data, "ro--")
plt.show()

# %%
plt.plot(x_data, y_data, "kh-.")
plt.show()

# %% [markdown]
# __Grids__

# %%
plt.plot(x_data, y_data, "ro--")
plt.grid()
plt.show()

# %% [markdown]
# <center> <h2 style="color:blue"> Multiple Graphs </h2> </center>

# %%
x_data = [1, 2, 3, 4, 5]
y_data_1 = [1, 2, 3, 4, 5]
y_data_2 = [1, 4, 9, 16, 25]
y_data_3 = [1.5, 2.17, 7, 5, 14]

# %%
plt.plot(x_data, y_data_1, "r")
plt.plot(x_data, y_data_2, "b")
plt.scatter(x_data, y_data_3, color="#265808")
plt.show()

# %% [markdown]
# <center> <h1 style="color:magenta"> Charts Compherensive </h1> </center>

# %% [markdown]
# <h2 style="color:dodgerblue">Line Plot </h2>

# %%
x = np.arange(0,1,0.01)
y = np.sqrt(x)

# %%
plt.plot(x, y)
plt.plot(x,x)
plt.plot(x, x**2)
plt.show()

# %% [markdown]
# <h2 style="color:dodgerblue">Line Plot </h2>

# %%
categories = ['A', 'B', 'C', 'D']
values = [25, 40, 30, 35]

# %%
plt.bar(categories, values)
plt.ylim(0,100)
plt.show()

# %% [markdown]
# <h2 style="color:dodgerblue">Scatter Plot </h2>

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [0.7, 3, 4.4, 3, 5.2]

# %%
plt.scatter(x, y)
plt.plot(x, x)
plt.show()

# %% [markdown]
# <h2 style="color:dodgerblue">Pie Plot </h2>

# %%
# Sample data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie Plot Example')
plt.axis('equal')
plt.show()

# %% [markdown]
# <h2 style="color:dodgerblue">Area Plot </h2>

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 4, 6, 8, 10]

# %%
plt.fill_between(x, y1, color="#265808", alpha=0.4)
plt.fill_between(x, y2, color="dodgerblue", alpha=0.4)
plt.show()

# %% [markdown]
# <h2 style="color:dodgerblue">Histogram Plot </h2>

# %%
# Frequency

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins=30, color='#265808', edgecolor='black')
plt.show()

# %% [markdown]
# <center> <h1 style="color:dodgerblue"> Tutorials </h1>  </center>

# %% [markdown]
# $$ x ~~ \epsilon ~~ (-\pi, \pi)$$
# <br>
# $$ f(x) = sin(x) $$

# %% [markdown]
# $$ x ~~ \epsilon ~~ (-\pi, \pi)$$
# <br>
# $$ f(x) = sin(x)$$
# <br>
# $$ g(x) = cos(2x)$$

# %% [markdown]
# $$ x ~~ \epsilon ~~ (1, 12)$$
# <br>
# $$ f(x) = \frac {sin(x)\cdot \sqrt {x}}  {x^2 +1} $$

# %% [markdown]
# $$ x ~~ \epsilon ~~ (0,1)$$
# <br>
# $$ f(x) = e^{2x} \cdot \sqrt {x} \cdot \frac{1} {x + \pi}$$

# %% [markdown]
# $$ x ~~ \epsilon ~~ (-\pi, \pi)$$
# <br>
# $$ f(x) = sin(x)$$
